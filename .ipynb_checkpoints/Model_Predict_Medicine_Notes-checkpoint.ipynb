# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('Doctor_Asiful_Sk.csv')

# %%
df
# Out:
#      Doctor ID                    Symptom  \
# 0        60897                   Bodyache
# 1        60897                      Fever
# 2        60897                 Chest pain
# 3        60897                      Fever
# 4        60897                   Headache
# ..         ...                        ...
# 543      60897           dryness of mouth
# 544      60897  Burning Pain On Urination
# 545      60897             Abdominal pain
# 546      60897                   Vomiting
# 547      60897    Pus At anorectal region
#
#                                          Prescriptions  \
# 0    CALPOL 500MG (50654); PARACETAMOL (500MG) (51603)
# 1    CALPOL 500MG (50654); PARACETAMOL (500MG) (51603)
# 2    CALPOL 500MG (50654); PARACETAMOL (500MG) (51603)
# 3    CALPOL 500MG (50654); PARACETAMOL (500MG) (51603)
# 4    CALPOL 500MG (50654); PARACETAMOL (500MG) (51603)
# ..                                                 ...
# 543                          Rest DSR Capsule (157441)
# 544                          Rest DSR Capsule (157441)
# 545                                                NaN
# 546                                                NaN
# 547                                                NaN
#
#                                               Dignosis  \
# 0                                                   ()
# 1                                                   ()
# 2                                                   ()
# 3                                                   ()
# 4                                                   ()
# ..                                                 ...
# 543  ('ACS - Acute coronary syndrome', 'UTI - Urina...
# 544  ('ACS - Acute coronary syndrome', 'UTI - Urina...
# 545  ('ACUTE VIRAL FEVER', 'Enteric fever', 'UTI - ...
# 546  ('ACUTE VIRAL FEVER', 'Enteric fever', 'UTI - ...
# 547  ('ACUTE VIRAL FEVER', 'Enteric fever', 'UTI - ...
#
#                                                  Notes
# 0    No sugar - no sweet in diet. to take rice & po...
# 1    No sugar - no sweet in diet. to take rice & po...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 543  No sugar - no sweet in diet. to take rice & po...
# 544  No sugar - no sweet in diet. to take rice & po...
# 545                                                NaN
# 546                                                NaN
# 547                                                NaN
#
# [548 rows x 5 columns]

# %%
# Encoding categorical variables
le_symptom = LabelEncoder()
df['Symptom_encoded'] = le_symptom.fit_transform(df['Symptom'])

le_medicine = LabelEncoder()#Encon
df['Medicine_encoded'] = le_medicine.fit_transform(df['Prescriptions'])

le_notes = LabelEncoder()
df['Notes_encoded'] = le_notes.fit_transform(df['Notes'])

le_dignosis = LabelEncoder()
df['Dignosis_encoded'] = le_dignosis.fit_transform(df['Dignosis'])

# %%
# Feature matrix and target variable
X = df[['Symptom_encoded']]  # You might want to include more features
y = df[['Medicine_encoded','Notes_encoded']]

# %%
def data_split(data, ratio):
    np.random.seed(42)
    shuffled = np.random.permutation(len(data))
    test_set_size = int(len(data) * ratio)
    test_indices = shuffled[:test_set_size]
    train_indices = shuffled[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
train, test = data_split(df, 0.2)

# %%
train
# Out:
#      Doctor ID                      Symptom  \
# 302      60897      swelling over right leg
# 46       60897               Abdominal pain
# 93       60897                     Numbness
# 464      60897                   Chest pain
# 321      60897            Fever With Chills
# ..         ...                          ...
# 71       60897                   Joint pain
# 106      60897            Fever With Chills
# 270      60897                        Cough
# 435      60897              COUGH WITH COLD
# 102      60897  generalized aches and pains
#
#                                          Prescriptions           Dignosis  \
# 302  Meftal-Spas Tablet (157457); Mpx-Cv 625 Tablet...                 ()
# 46                                                 NaN      ('Cvstroke',)
# 93                                                 NaN                 ()
# 464  Arkamin Tablet (157527); Micatel-M 40Mg/50Mg T...                 ()
# 321  Pantin (157483); emset (157484); iv fluids NS ...  ('Dengue fever',)
# ..                                                 ...                ...
# 71          MONTICOPE TABLET (123620); asdasd (126277)                 ()
# 106  Alastin 10Mg Tablet (157452); Azee 500 Tablet ...                 ()
# 270  Alastin 10Mg Tablet (157452); Azee 500 Tablet ...                 ()
# 435  Alastin 10Mg Tablet (157452); Azee 500 Tablet ...                 ()
# 102  Alastin 10Mg Tablet (157452); Azee 500 Tablet ...                 ()
#
#     Notes  Symptom_encoded  Medicine_encoded  Notes_encoded  Dignosis_encoded
# 302   NaN               64                47              4                12
# 46    NaN                2                55              4                 7
# 93    NaN               46                55              4                12
# 464   NaN               15                11              4                12
# 321   NaN               28                53              4                 9
# ..    ...              ...               ...            ...               ...
# 71    NaN               37                45              4                12
# 106   NaN               28                 5              4                12
# 270   NaN               17                 5              4                12
# 435   NaN               13                 6              4                12
# 102   NaN               62                 5              4                12
#
# [439 rows x 9 columns]

# %%
test
# Out:
#      Doctor ID                             Symptom  \
# 247      60897                            Vomiting
# 78       60897                      Abdominal pain
# 245      60897                   Fever With Chills
# 353      60897                      Bleeding piles
# 477      60897                            RIF pain
# ..         ...                                 ...
# 153      60897                               Cough
# 15       60897                              Nausea
# 332      60897                        Constipation
# 39       60897                  Frequency of stool
# 54       60897  Cough with yellowish expectoration
#
#                                          Prescriptions  \
# 247  Chymonet Ap Tablet (157575); Monocef 1Gm Injec...
# 78                                                 NaN
# 245  Chymonet Ap Tablet (157575); Monocef 1Gm Injec...
# 353  Dan-P Tablet (157558); Duphalac  Lemon Oral So...
# 477  Drowel-M Tablet (157458); Meftal-Spas Tablet (...
# ..                                                 ...
# 153  Alastin 10Mg Tablet (157452); Azee 500 Tablet ...
# 15   AGINAL AT (50652); CALPOL 500MG (50654); TELKO...
# 332  Arkamin Tablet (157527); Duphalac  Lemon Oral ...
# 39   CALPOL 500MG (50654); PARACETAMOL (500MG) (51603)
# 54     PARACETAMOL (500MG) (51603); TELKONOL-M (50650)
#
#                              Dignosis Notes  Symptom_encoded  \
# 247  ('Left Cervical Lymphadenitis',)   NaN               57
# 78                                 ()   NaN                2
# 245  ('Left Cervical Lymphadenitis',)   NaN               28
# 353    ('4th Degree Extrenal Piles',)   NaN                7
# 477                                ()   NaN               50
# ..                                ...   ...              ...
# 153                                ()   NaN               17
# 15                                 ()   NaN               43
# 332                                ()   NaN               16
# 39                                 ()   NaN               31
# 54                                 ()   NaN               19
#
#      Medicine_encoded  Notes_encoded  Dignosis_encoded
# 247                27              4                10
# 78                 55              4                12
# 245                27              4                10
# 353                33              4                 3
# 477                39              4                12
# ..                ...            ...               ...
# 153                 5              4                12
# 15                  0              4                12
# 332                10              4                12
# 39                 25              4                12
# 54                 52              4                12
#
# [109 rows x 9 columns]

# %%
X_train = train[['Symptom_encoded']].to_numpy()
X_test = test[['Symptom_encoded']].to_numpy()

# %%
Y_train = train[['Medicine_encoded']].to_numpy()
Y_test = test[['Medicine_encoded']].to_numpy()

# %%
y_train = train[['Notes_encoded']].to_numpy()
y_test = test[['Notes_encoded']].to_numpy()

# %%
z_train = train[['Dignosis_encoded']].to_numpy()
z_test = test[['Dignosis_encoded']].to_numpy()

# %%
model1 = RandomForestClassifier(n_estimators=100, random_state=42)
model1.fit(X_train, y_train)
# Out:
# C:\Users\Dhruveel\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(random_state=42)

# %%
model2 = RandomForestClassifier(n_estimators=100, random_state=42)
model2.fit(X_train, Y_train)
# Out:
# C:\Users\Dhruveel\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(random_state=42)

# %%
model3 = RandomForestClassifier(n_estimators=100, random_state=42)
model3.fit(X_train, z_train)
# Out:
# C:\Users\Dhruveel\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(random_state=42)

# %%
df
# Out:
#      Doctor ID                    Symptom  \
# 0        60897                   Bodyache
# 1        60897                      Fever
# 2        60897                 Chest pain
# 3        60897                      Fever
# 4        60897                   Headache
# ..         ...                        ...
# 543      60897           dryness of mouth
# 544      60897  Burning Pain On Urination
# 545      60897             Abdominal pain
# 546      60897                   Vomiting
# 547      60897    Pus At anorectal region
#
#                                          Prescriptions  \
# 0    CALPOL 500MG (50654); PARACETAMOL (500MG) (51603)
# 1    CALPOL 500MG (50654); PARACETAMOL (500MG) (51603)
# 2    CALPOL 500MG (50654); PARACETAMOL (500MG) (51603)
# 3    CALPOL 500MG (50654); PARACETAMOL (500MG) (51603)
# 4    CALPOL 500MG (50654); PARACETAMOL (500MG) (51603)
# ..                                                 ...
# 543                          Rest DSR Capsule (157441)
# 544                          Rest DSR Capsule (157441)
# 545                                                NaN
# 546                                                NaN
# 547                                                NaN
#
#                                               Dignosis  \
# 0                                                   ()
# 1                                                   ()
# 2                                                   ()
# 3                                                   ()
# 4                                                   ()
# ..                                                 ...
# 543  ('ACS - Acute coronary syndrome', 'UTI - Urina...
# 544  ('ACS - Acute coronary syndrome', 'UTI - Urina...
# 545  ('ACUTE VIRAL FEVER', 'Enteric fever', 'UTI - ...
# 546  ('ACUTE VIRAL FEVER', 'Enteric fever', 'UTI - ...
# 547  ('ACUTE VIRAL FEVER', 'Enteric fever', 'UTI - ...
#
#                                                  Notes  Symptom_encoded  \
# 0    No sugar - no sweet in diet. to take rice & po...                8
# 1    No sugar - no sweet in diet. to take rice & po...               27
# 2                                                  NaN               15
# 3                                                  NaN               27
# 4                                                  NaN               35
# ..                                                 ...              ...
# 543  No sugar - no sweet in diet. to take rice & po...               59
# 544  No sugar - no sweet in diet. to take rice & po...               11
# 545                                                NaN                2
# 546                                                NaN               57
# 547                                                NaN               49
#
#      Medicine_encoded  Notes_encoded  Dignosis_encoded
# 0                  25              2                12
# 1                  25              2                12
# 2                  25              4                12
# 3                  25              4                12
# 4                  25              4                12
# ..                ...            ...               ...
# 543                54              3                 4
# 544                54              3                 4
# 545                55              4                 5
# 546                55              4                 5
# 547                55              4                 5
#
# [548 rows x 9 columns]

# %%
# Assume symptoms_list is a list of symptoms
symptoms_list = ['Bodyache', 'dryness of mouth', 'Burning Pain On Urination']

# Initialize lists to store predictions for each symptom
predicted_notes_encoded_list = []
predicted_medicine_encoded_list = []
predicted_diagnosis_encoded_list = []

# Loop through each symptom
for symptom in symptoms_list:
    # Encode the symptom
    new_symptom_encoded = le_symptom.transform([symptom])
    
    # Predict notes, medicine, and diagnosis for the symptom
    predicted_notes_encoded = model1.predict([new_symptom_encoded])
    predicted_medicine_encoded = model2.predict([new_symptom_encoded])
    predicted_diagnosis_encoded = model3.predict([new_symptom_encoded])
    
    # Append predictions to lists
    predicted_notes_encoded_list.append(predicted_notes_encoded)
    predicted_medicine_encoded_list.append(predicted_medicine_encoded)
    predicted_diagnosis_encoded_list.append(predicted_diagnosis_encoded)

# Decode the predictions
predicted_notes = le_notes.inverse_transform(predicted_notes_encoded_list)
predicted_medicine = le_medicine.inverse_transform(predicted_medicine_encoded_list)
predicted_diagnosis = le_dignosis.inverse_transform(predicted_diagnosis_encoded_list)

# Now you have lists of predicted notes, medicine, and diagnosis for each symptom in symptoms_list
# Out:
# C:\Users\Dhruveel\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:153: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Dhruveel\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:153: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Dhruveel\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:153: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# new_symptom_encoded = le_symptom.transform(['Frequency of stool'])

# predicted_medicine_encoded = model2.predict([new_symptom_encoded])
# predicted_notes_encoded = model1.predict([new_symptom_encoded])
# predicted_dignosis_encoded = model3.predict([new_symptom_encoded])

# predicted_notes = le_notes.inverse_transform(predicted_notes_encoded)
# predicted_medicine = le_medicine.inverse_transform(predicted_medicine_encoded)
# predicted_dignosis = le_dignosis.inverse_transform(predicted_dignosis_encoded)

# %%
print(f"Predicted Medicine: {predicted_medicine[0]}")
print(f"predicted_notes: {predicted_notes[0]}")
print(f"predicted_dignosis: {predicted_diagnosis[0]}")
# Out:
# Predicted Medicine: nan
# predicted_notes: nan
# predicted_dignosis: ()

# %%
notes = ''
medicine = ''
dignosis = ''

if 'nan' in predicted_medicine:
    notes = predicted_notes[0]
    medicine = predicted_medicine[0]
    dignosis = predicted_diagnosis[0]

dataframe2 = pd.DataFrame({
    'Medicine': medicine,
    'Notes': notes,
    'Dognosis':dignosis
})

# %%
dataframe2 = pd.DataFrame({
    'Medicine': medicine,
    'Notes': notes,
    'Dognosis':dignosis
})

else:
    notes = predicted_notes[0]
    medicine = predicted_medicine[0].split(';')
    dignosis = predicted_diagnosis[0]
    
    dataframe2 = pd.DataFrame({
        'Medicine': medicine,
        'Notes': notes,
        'Dognosis':dignosis
    })

# %%
dataframe2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 dataframe2
#
# NameError: name 'dataframe2' is not defined

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('doctor_Asiful_Sk.csv')

# %%
df
# Out:
#      Doctor ID                    Symptom  \
# 0        60897                   Bodyache
# 1        60897                      Fever
# 2        60897                 Chest pain
# 3        60897                      Fever
# 4        60897                   Headache
# ..         ...                        ...
# 543      60897           dryness of mouth
# 544      60897  Burning Pain On Urination
# 545      60897             Abdominal pain
# 546      60897                   Vomiting
# 547      60897    Pus At anorectal region
#
#                                          Prescriptions  \
# 0    CALPOL 500MG (50654); PARACETAMOL (500MG) (51603)
# 1    CALPOL 500MG (50654); PARACETAMOL (500MG) (51603)
# 2    CALPOL 500MG (50654); PARACETAMOL (500MG) (51603)
# 3    CALPOL 500MG (50654); PARACETAMOL (500MG) (51603)
# 4    CALPOL 500MG (50654); PARACETAMOL (500MG) (51603)
# ..                                                 ...
# 543                          Rest DSR Capsule (157441)
# 544                          Rest DSR Capsule (157441)
# 545                                                NaN
# 546                                                NaN
# 547                                                NaN
#
#                                               Dignosis  \
# 0                                                   ()
# 1                                                   ()
# 2                                                   ()
# 3                                                   ()
# 4                                                   ()
# ..                                                 ...
# 543  ('ACS - Acute coronary syndrome', 'UTI - Urina...
# 544  ('ACS - Acute coronary syndrome', 'UTI - Urina...
# 545  ('ACUTE VIRAL FEVER', 'Enteric fever', 'UTI - ...
# 546  ('ACUTE VIRAL FEVER', 'Enteric fever', 'UTI - ...
# 547  ('ACUTE VIRAL FEVER', 'Enteric fever', 'UTI - ...
#
#                                                  Notes
# 0    No sugar - no sweet in diet. to take rice & po...
# 1    No sugar - no sweet in diet. to take rice & po...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 543  No sugar - no sweet in diet. to take rice & po...
# 544  No sugar - no sweet in diet. to take rice & po...
# 545                                                NaN
# 546                                                NaN
# 547                                                NaN
#
# [548 rows x 5 columns]

# %%
# Encoding categorical variables
le_symptom = LabelEncoder()
df['Symptom_encoded'] = le_symptom.fit_transform(df['Symptom'])

le_medicine = LabelEncoder()
df['Medicine_encoded'] = le_medicine.fit_transform(df['Prescriptions'])

le_notes = LabelEncoder()
df['Notes_encoded'] = le_notes.fit_transform(df['Notes'])

le_dignosis = LabelEncoder()
df['Dignosis_encoded'] = le_dignosis.fit_transform(df['Dignosis'])

# %%
def data_split(data, ratio):
    np.random.seed(42)
    shuffled = np.random.permutation(len(data))
    test_set_size = int(len(data) * ratio)
    test_indices = shuffled[:test_set_size]
    train_indices = shuffled[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
train, test = data_split(df, 0.4)

# %%
X_train = train[['Symptom_encoded']].to_numpy()
X_test = test[['Symptom_encoded']].to_numpy()

# %%
Y_train = train[['Medicine_encoded']].to_numpy()
Y_test = test[['Medicine_encoded']].to_numpy()

# %%
Z_train = train[['Notes_encoded']].to_numpy()
Z_test = test[['Notes_encoded']].to_numpy()

# %%
W_train = train[['Dignosis_encoded']].to_numpy()
W_test = test[['Dignosis_encoded']].to_numpy()

# %%
model_med = RandomForestClassifier(n_estimators=100, random_state=42)
model_med.fit(X_train, Y_train)
# Out:
# C:\Users\Dhruveel\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(random_state=42)

# %%
model_not = RandomForestClassifier(n_estimators=100, random_state=42)
model_not.fit(X_train, Z_train)
# Out:
# C:\Users\Dhruveel\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(random_state=42)

# %%
model_dig = RandomForestClassifier(n_estimators=100, random_state=42)
model_dig.fit(X_train, W_train)
# Out:
# C:\Users\Dhruveel\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(random_state=42)

# %%
# Assume symptoms_list is a list of symptoms
symptoms_list = ['Chest pain','Burning Pain On Urination','Headache']

# %%
# Initialize lists to store predictions for each symptom
predicted_notes_encoded_list = []
predicted_medicine_encoded_list = []
predicted_diagnosis_encoded_list = []

# %%
# Loop through each symptom
for symptom in symptoms_list:
    # Encode the symptom
    new_symptom_encoded = le_symptom.transform([symptom])
    
    # Predict notes, medicine, and diagnosis for the symptom
    predicted_medicine_encoded = model_med.predict([new_symptom_encoded])
    predicted_notes_encoded = model_not.predict([new_symptom_encoded])
    predicted_diagnosis_encoded = model_dig.predict([new_symptom_encoded])
    
    # Append predictions to lists
    predicted_notes_encoded_list.append(predicted_notes_encoded)
    predicted_medicine_encoded_list.append(predicted_medicine_encoded)
    predicted_diagnosis_encoded_list.append(predicted_diagnosis_encoded)

# %%
# Decode the predictions
predicted_notes = le_notes.inverse_transform(predicted_notes_encoded_list)
predicted_medicine = le_medicine.inverse_transform(predicted_medicine_encoded_list)
predicted_diagnosis = le_dignosis.inverse_transform(predicted_diagnosis_encoded_list)
# Out:
# C:\Users\Dhruveel\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:153: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Dhruveel\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:153: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\Dhruveel\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:153: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
print(f"Predicted Medicine: {predicted_medicine[0]}")
print(f"predicted_notes: {predicted_notes[0]}")
print(f"predicted_dignosis: {predicted_diagnosis[0]}")
# Out:
# Predicted Medicine: Canator 80 (157515); Clexane 60Mg Injection (157514); Clopilet Tablet (157510); Duphalac  Lemon Oral Solution (157470); Ecosprin 150 Tablet (157509); Mirel 18Mg Injection (157513); Monocef 1Gm Injection (157495); Ntg 5Mg Injection (157516); Pantin (157483); Stresnil 0.5 Tablet (157456); emset (157484)
# predicted_notes: nan
# predicted_dignosis: ()

# %%
data = {
    'Symptom': symptoms_list,
    'Predicted Medicine': predicted_medicine,
    'Predicted Notes': predicted_notes,
    'Predicted Diagnosis': predicted_diagnosis
}

df_predictions = pd.DataFrame(data)

df_predictions
# Out:
#                      Symptom  \
# 0                 Chest pain
# 1  Burning Pain On Urination
# 2                   Headache
#
#                                   Predicted Medicine Predicted Notes  \
# 0  Canator 80 (157515); Clexane 60Mg Injection (1...             NaN
# 1  Citralka Liquid Syrup (157442); Dolo 650 Table...             NaN
# 2  Alastin 10Mg Tablet (157452); Azee 500 Tablet ...             NaN
#
#   Predicted Diagnosis
# 0                  ()
# 1                  ()
# 2                  ()

# %%
d = df_predictions.to_csv('123.csv')

# %%
df_predictions['Predicted Medicine']
# Out:
# 0    Canator 80 (157515); Clexane 60Mg Injection (1...
# 1    Citralka Liquid Syrup (157442); Dolo 650 Table...
# 2    Alastin 10Mg Tablet (157452); Azee 500 Tablet ...
# Name: Predicted Medicine, dtype: object

# %%
notes = ''
medicine = ''
diagnosis = ''

# %%
if 'nan' in predicted_medicine:
    notes = predicted_notes
    medicine = predicted_medicine
    diagnosis = predicted_diagnosis
else:
    notes = predicted_notes
    # Check if predicted_medicine[0] is a string before splitting
    if isinstance(predicted_medicine, str):
        medicine = predicted_medicine.split(';')
    else:
        medicine = predicted_medicine
    diagnosis = predicted_diagnosis

# %%
# Ensure notes, medicine, and diagnosis are always treated as lists
notes = [notes] if isinstance(notes, str) else notes
medicine = [medicine] if isinstance(medicine, str) else medicine
diagnosis = [diagnosis] if isinstance(diagnosis, str) else diagnosis

# %%
medicine
# Out:
# array(['Canator 80 (157515); Clexane 60Mg Injection (157514); Clopilet Tablet (157510); Duphalac  Lemon Oral Solution (157470); Ecosprin 150 Tablet (157509); Mirel 18Mg Injection (157513); Monocef 1Gm Injection (157495); Ntg 5Mg Injection (157516); Pantin (157483); Stresnil 0.5 Tablet (157456); emset (157484)',
#        'Citralka Liquid Syrup (157442); Dolo 650 Tablet (157440); Elisita DM (157444); Gerzone 1000 Mg/500 Mg Injection (157438); Rest DSR Capsule (157441); Tri-Bitglim 2mg/15mg/500mg Tablet (157443); Urosafe 100Mg Tablet (157439)',
#        'Alastin 10Mg Tablet (157452); Azee 500 Tablet (157450); Coldmine Tablet (157451); GRELIREX SYP (157453); Rest DSR Capsule (157441); Telvas 3D Tablet (157454)'],
#       dtype=object)

# %%
# Check if notes, medicine, and diagnosis are lists, and if so, get the first element as scalar values
notes_scalar = notes[0] if isinstance(notes, list) else notes
medicine_scalar = medicine[0] if isinstance(medicine, list) else medicine
diagnosis_scalar = diagnosis[0] if isinstance(diagnosis, list) else diagnosis

# %%
medicine_scalar
# Out:
# array(['Canator 80 (157515); Clexane 60Mg Injection (157514); Clopilet Tablet (157510); Duphalac  Lemon Oral Solution (157470); Ecosprin 150 Tablet (157509); Mirel 18Mg Injection (157513); Monocef 1Gm Injection (157495); Ntg 5Mg Injection (157516); Pantin (157483); Stresnil 0.5 Tablet (157456); emset (157484)',
#        'Citralka Liquid Syrup (157442); Dolo 650 Tablet (157440); Elisita DM (157444); Gerzone 1000 Mg/500 Mg Injection (157438); Rest DSR Capsule (157441); Tri-Bitglim 2mg/15mg/500mg Tablet (157443); Urosafe 100Mg Tablet (157439)',
#        'Alastin 10Mg Tablet (157452); Azee 500 Tablet (157450); Coldmine Tablet (157451); GRELIREX SYP (157453); Rest DSR Capsule (157441); Telvas 3D Tablet (157454)'],
#       dtype=object)

# %%
# Create DataFrame with scalar values
dataframe2 = pd.DataFrame({
    'Medicine': [medicine_scalar],
    'Notes': [notes_scalar],
    'Diagnosis': [diagnosis_scalar]
})

# %%
dataframe2
# Out:
#                                             Medicine            Notes  \
# 0  [Canator 80 (157515); Clexane 60Mg Injection (...  [nan, nan, nan]
#
#       Diagnosis
# 0  [(), (), ()]

# %%
new_symptom_encoded = le_symptom.transform(['Difficulty in closing left eye'])

predicted_medicine_encoded = model_med.predict([new_symptom_encoded])
predicted_notes_encoded = model_not.predict([new_symptom_encoded])
predicted_dignosis_encoded = model_dig.predict([new_symptom_encoded])

predicted_medicine = le_medicine.inverse_transform(predicted_medicine_encoded)
predicted_notes = le_notes.inverse_transform(predicted_notes_encoded)
predicted_dignosis = le_dignosis.inverse_transform(predicted_dignosis_encoded)

# %%
print(f"Predicted Medicine: {predicted_medicine[0]}")
print(f"predicted_notes: {predicted_notes[0]}")
print(f"predicted_dignosis: {predicted_dignosis[0]}")

# %%
medicine = predicted_medicine[0].split(';')
notes = predicted_notes[0]
dignosis = predicted_dignosis[0]

# %%
dataframe2 = pd.DataFrame({
    'Medicine': medicine,
    'Notes': notes,
    'Diagnosis':dignosis
})

# %%
dataframe2
